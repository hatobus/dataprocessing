# %%
import pandas as pd

# %%
url = "https://findy-code.io/engineer-lab/findy-tech-company-top-100-201705"
df = pd.io.html.read_html(url)

# %%
df
# Out:
# [    順位                 社名  求人票のわかりやすさ\n(40点）  求人票のエンジニア魅力度\n(40点）  \
#  0    1         GMOペパボ株式会社                 34                   36
#  1    2         クックパッド株式会社                 32                   36
#  2    3             株式会社一休                 32                   38
#  3    〃          株式会社レアジョブ                 36                   34
#  4    5           株式会社ドワンゴ                 34                   32
#  5    〃           メドピア株式会社                 32                   38
#  6    〃           ラクスル株式会社                 34                   36
#  7    8          株式会社ビズリーチ                 28                   34
#  8    〃           クルーズ株式会社                 32                   32
#  9    〃         株式会社LIFULL                 32                   32
#  10   〃     さくらインターネット株式会社                 32                   34
#  11  12             楽天株式会社                 30                   30
#  12   〃        株式会社DMM.com                 32                   28
# ...

# %%
dftop27 = df[0]
dftop63 = df[1]
dftop100 = df[2]

# %%
df100 = pd.concat([dftop27,dftop63,dftop100])

# %%
df100
# Out:
#     順位                       社名  求人票のわかりやすさ\n(40点）  求人票のエンジニア魅力度\n(40点）  \
# 0    1               GMOペパボ株式会社                 34                   36
# 1    2               クックパッド株式会社                 32                   36
# 2    3                   株式会社一休                 32                   38
# 3    〃                株式会社レアジョブ                 36                   34
# 4    5                 株式会社ドワンゴ                 34                   32
# 5    〃                 メドピア株式会社                 32                   38
# 6    〃                 ラクスル株式会社                 34                   36
# 7    8                株式会社ビズリーチ                 28                   34
# 8    〃                 クルーズ株式会社                 32                   32
# 9    〃               株式会社LIFULL                 32                   32
# 10   〃           さくらインターネット株式会社                 32                   34
# 11  12                   楽天株式会社                 30                   30
# ...

# %%
df100.to_csv("FindlyTechTop100.csv")
