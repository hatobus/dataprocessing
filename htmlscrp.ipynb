# %%
import pandas as pd

# %%
url = "http://web-ext.u-aizu.ac.jp/official/curriculum/syllabus/2017_1_J_001.html"
df = pd.io.html.read_html(url)

# %%
df[1::2]
# Out:
# [         0
#  0  科目一覧へ戻る,                                                    0  \
#  0                                更新日／Last updated on
#  1                               授業の概要／Course outline
#  2         授業の目的と到達目標／Objectives and attainment goals
#  3                            授業スケジュール／Class schedule
#  4                                    教科書／Textbook(s)
#  5                 成績評価の方法・基準／Grading method/criteria
#  6  参考(授業ホームページ、図書など)／Reference (coursewebsite, li...
#
#                                                     1
#  0                                         2017/01/23
#  1  西洋哲学は、philosophiaというギリシア語の原語が示すように、「知を愛する」ことから...
#  2  ・授業で取り上げるテーマについて、主要な立場を理解し、明確に述べることができる。・各テーマに...
#  3  ・哲学の起源と展開（2コマ）・懐疑論と認識論（2コマ）・外界世界と観念論（2コマ）・現代の心...
#  4                              教科書は指定せず、ハンドアウトを配布する。
#  5  クラス内でのミニクイズ（30%）、レポート（30%）、定期試験（40%）により評価する。詳細...
#  6  指し当たっては以下のものが初学者にも読みやすく、推奨できる。T.ネーゲル（岡本裕一郎・若松良...  ,                                                    0  \
# ...
