# %%
import pandas as pd,numpy as np

# %%
url = 'https://ja.wikipedia.org/wiki/%E6%97%A5%E6%9C%AC%E3%81%AE%E3%83%86%E3%83%AC%E3%83%93%E3%82%A2%E3%83%8B%E3%83%A1%E4%BD%9C%E5%93%81%E4%B8%80%E8%A6%A7_(2000%E5%B9%B4%E4%BB%A3_%E5%BE%8C%E5%8D%8A)'
df = pd.io.html.read_html(url)

# %%
del df[:0]

# %%
del df[1]

# %%
del df[0:8]

# %%
df3.columns=['開始日 - 終了日','作品名','制作会社','主放送局・系列','話数']

# %%
print(type(df))
# Out:
# <class 'list'>

# %%
df2 = pd.Series(df)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-30d1b36d8a16> in <module>()
# ----> 1 df2.作品名
#
# /Users/openapplabn/.pyenv/versions/anaconda3-4.3.0/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute '作品名'

# %%
df3 = pd.concat([df2[0], df2[1],df[2],df2[3],df[4],df[5],df[6],df[7],df[8],df[9],df2[10], df2[11],df[12],df2[13],df[14],df[15],df[16],df[17],df[18],df[19]])

# %%
df3
# Out:
#               開始日 - 終了日                                           作品名  \
# 0             開始日 - 終了日                                           作品名
# 1          1月1日 - 3月26日                                       まじかるカナン
# 2            1月2日（特別番組）                     こちら葛飾区亀有公園前派出所「マグロに乗った警官」
# 3            1月3日（特別番組）                   DIGITAL MONSTER X-evolution
# 4          1月4日 - 3月29日                  らいむいろ流奇譚X cross 〜恋、教ヘテクダサイ。〜
# 5          1月5日 - 3月23日                                  JINKI:EXTEND
# 6          1月5日 - 3月30日                                スターシップ・オペレーターズ
# 7          1月5日 - 3月23日                        Xenosaga THE ANIMATION
# 8          1月5日 - 6月29日                                      魔法先生ネギま!
# 9           1月6日 - 7月7日                                      ああっ女神さまっ
# 10         1月6日 - 3月31日                                           AIR
# 11         1月7日 - 3月25日                             アークエとガッチンポー てんこもり
# ...

# %%
df3
# Out:
#               開始日 - 終了日                                           作品名  \
# 0             開始日 - 終了日                                           作品名
# 1          1月1日 - 3月26日                                       まじかるカナン
# 2            1月2日（特別番組）                     こちら葛飾区亀有公園前派出所「マグロに乗った警官」
# 3            1月3日（特別番組）                   DIGITAL MONSTER X-evolution
# 4          1月4日 - 3月29日                  らいむいろ流奇譚X cross 〜恋、教ヘテクダサイ。〜
# 5          1月5日 - 3月23日                                  JINKI:EXTEND
# 6          1月5日 - 3月30日                                スターシップ・オペレーターズ
# 7          1月5日 - 3月23日                        Xenosaga THE ANIMATION
# 8          1月5日 - 6月29日                                      魔法先生ネギま!
# 9           1月6日 - 7月7日                                      ああっ女神さまっ
# 10         1月6日 - 3月31日                                           AIR
# 11         1月7日 - 3月25日                             アークエとガッチンポー てんこもり
# ...

# %%
df3.to_csv( 'jpnanime2000after.csv' )

# %%
df4 = df3
